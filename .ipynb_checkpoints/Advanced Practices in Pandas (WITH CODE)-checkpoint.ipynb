# %% [markdown]
# # DS3 Kaggle Workshop - Advanced Practices in Pandas
#
# Welcome to our Advanced Practices in Pandas Jupyter Notebook. With our interactive problems, we hope to guide you in your learning process. Here, you can practice useful pandas functions for DataFrame manipulation and analysis. Have fun!

# %% [markdown]
# The dataset we will be using is called “Uber and Lyft Cab Prices” from Kaggle. Here is the link to the dataset: https://www.kaggle.com/ravi72munde/uber-lyft-cab-prices?select=weather.csv. For easier access, we have downloaded it into the same repository as this Jupyter Notebook for you.
#
# **Note.** The slideshow presentation will be published after the workshop. This will allow you to look back at the material covered and go over concepts that we were not able to get to during the timeframe.

# %% [markdown]
# ## Importing Libraries and the Dataset

# %%
import pandas as pd
import numpy as np

# %%
cab_rides = pd.read_csv('cab_rides.csv')

# %%
weather = pd.read_csv('weather.csv')

# %% [markdown]
# ## Concatenation

# %% [markdown]
# ## Merge and Join

# %% [markdown]
# ## Transpose

# %%
ten_cabs= cab_rides.head(10)
ten_cabs
# Out:
#    distance cab_type     time_stamp              destination  \
# 0      0.44     Lyft  1544952607890            North Station
# 1      0.44     Lyft  1543284023677            North Station
# 2      0.44     Lyft  1543366822198            North Station
# 3      0.44     Lyft  1543553582749            North Station
# 4      0.44     Lyft  1543463360223            North Station
# 5      0.44     Lyft  1545071112138            North Station
# 6      1.08     Lyft  1543208580200  Northeastern University
# 7      1.08     Lyft  1543780384677  Northeastern University
# 8      1.08     Lyft  1543818482645  Northeastern University
# 9      1.08     Lyft  1543315522249  Northeastern University
#
#              source  price  surge_multiplier  \
# 0  Haymarket Square    5.0               1.0
# 1  Haymarket Square   11.0               1.0
# 2  Haymarket Square    7.0               1.0
# 3  Haymarket Square   26.0               1.0
# 4  Haymarket Square    9.0               1.0
# 5  Haymarket Square   16.5               1.0
# 6          Back Bay   10.5               1.0
# 7          Back Bay   16.5               1.0
# 8          Back Bay    3.0               1.0
# 9          Back Bay   27.5               1.0
#
#                                      id    product_id          name
# 0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7     lyft_line        Shared
# 1  4bd23055-6827-41c6-b23b-3c491f24e74d  lyft_premier           Lux
# 2  981a3613-77af-4620-a42a-0c0866077d1e          lyft          Lyft
# 3  c2d88af2-d278-4bfd-a8d0-29ca77cc5512   lyft_luxsuv  Lux Black XL
# 4  e0126e1f-8ca9-4f2e-82b3-50505a09db9a     lyft_plus       Lyft XL
# 5  f6f6d7e4-3e18-4922-a5f5-181cdd3fa6f2      lyft_lux     Lux Black
# 6  462816a3-820d-408b-8549-0b39e82f65ac     lyft_plus       Lyft XL
# 7  474d6376-bc59-4ec9-bf57-4e6d6faeb165      lyft_lux     Lux Black
# 8  4f9fee41-fde3-4767-bbf1-a00e108701fb     lyft_line        Shared
# 9  8612d909-98b8-4454-a093-30bd48de0cb3   lyft_luxsuv  Lux Black XL

# %%
ten_cabs_transpose = ten_cabs.transpose() #same as .T
ten_cabs_transpose
# Out:
#                                                      0  \
# distance                                          0.44
# cab_type                                          Lyft
# time_stamp                               1544952607890
# destination                              North Station
# source                                Haymarket Square
# price                                                5
# surge_multiplier                                     1
# id                424553bb-7174-41ea-aeb4-fe06d4f4b9d7
# product_id                                   lyft_line
# name                                            Shared
#
#                                                      1  \
# distance                                          0.44
# cab_type                                          Lyft
# time_stamp                               1543284023677
# destination                              North Station
# source                                Haymarket Square
# price                                               11
# surge_multiplier                                     1
# id                4bd23055-6827-41c6-b23b-3c491f24e74d
# product_id                                lyft_premier
# name                                               Lux
#
#                                                      2  \
# distance                                          0.44
# cab_type                                          Lyft
# time_stamp                               1543366822198
# destination                              North Station
# source                                Haymarket Square
# price                                                7
# surge_multiplier                                     1
# id                981a3613-77af-4620-a42a-0c0866077d1e
# product_id                                        lyft
# name                                              Lyft
#
#                                                      3  \
# distance                                          0.44
# cab_type                                          Lyft
# time_stamp                               1543553582749
# destination                              North Station
# source                                Haymarket Square
# price                                               26
# surge_multiplier                                     1
# id                c2d88af2-d278-4bfd-a8d0-29ca77cc5512
# product_id                                 lyft_luxsuv
# name                                      Lux Black XL
#
#                                                      4  \
# distance                                          0.44
# cab_type                                          Lyft
# time_stamp                               1543463360223
# destination                              North Station
# source                                Haymarket Square
# price                                                9
# surge_multiplier                                     1
# id                e0126e1f-8ca9-4f2e-82b3-50505a09db9a
# product_id                                   lyft_plus
# name                                           Lyft XL
#
#                                                      5  \
# distance                                          0.44
# cab_type                                          Lyft
# time_stamp                               1545071112138
# destination                              North Station
# source                                Haymarket Square
# price                                             16.5
# surge_multiplier                                     1
# id                f6f6d7e4-3e18-4922-a5f5-181cdd3fa6f2
# product_id                                    lyft_lux
# name                                         Lux Black
#
#                                                      6  \
# distance                                          1.08
# cab_type                                          Lyft
# time_stamp                               1543208580200
# destination                    Northeastern University
# source                                        Back Bay
# price                                             10.5
# surge_multiplier                                     1
# id                462816a3-820d-408b-8549-0b39e82f65ac
# product_id                                   lyft_plus
# name                                           Lyft XL
#
#                                                      7  \
# distance                                          1.08
# cab_type                                          Lyft
# time_stamp                               1543780384677
# destination                    Northeastern University
# source                                        Back Bay
# price                                             16.5
# surge_multiplier                                     1
# id                474d6376-bc59-4ec9-bf57-4e6d6faeb165
# product_id                                    lyft_lux
# name                                         Lux Black
#
#                                                      8  \
# distance                                          1.08
# cab_type                                          Lyft
# time_stamp                               1543818482645
# destination                    Northeastern University
# source                                        Back Bay
# price                                                3
# surge_multiplier                                     1
# id                4f9fee41-fde3-4767-bbf1-a00e108701fb
# product_id                                   lyft_line
# name                                            Shared
#
#                                                      9
# distance                                          1.08
# cab_type                                          Lyft
# time_stamp                               1543315522249
# destination                    Northeastern University
# source                                        Back Bay
# price                                             27.5
# surge_multiplier                                     1
# id                8612d909-98b8-4454-a093-30bd48de0cb3
# product_id                                 lyft_luxsuv
# name                                      Lux Black XL

# %%
weather_transpose = weather.T # same as .transpose()
weather_transpose
# Out:
#                   0            1                  2           3     \
# temp             42.42        42.43               42.5       42.11
# location      Back Bay  Beacon Hill  Boston University      Fenway
# clouds               1            1                  1           1
# pressure       1012.14      1012.15            1012.15     1012.13
# rain            0.1228       0.1846             0.1089      0.0969
# time_stamp  1545003901   1545003901         1545003901  1545003901
# humidity          0.77         0.76               0.76        0.77
# wind             11.25        11.32              11.07       11.09
#
#                           4                 5           6              7     \
# temp                     43.13             42.34       42.36          42.21
# location    Financial District  Haymarket Square   North End  North Station
# clouds                       1                 1           1              1
# pressure               1012.14           1012.15     1012.15        1012.16
# rain                    0.1786            0.2068      0.2088         0.2069
# time_stamp          1545003901        1545003901  1545003901     1545003901
# humidity                  0.75              0.77        0.77           0.77
# wind                     11.49             11.49       11.46          11.37
#
#                                8              9     ...               6266  \
# temp                          42.07          43.05  ...              44.85
# location    Northeastern University  South Station  ...  Boston University
# clouds                            1              1  ...               0.89
# pressure                    1012.12        1012.12  ...             1000.7
# rain                          0.102         0.1547  ...                NaN
# time_stamp               1545003901     1545003901  ...         1543819974
# humidity                       0.78           0.75  ...               0.95
# wind                          11.28          11.58  ...               1.52
#
#                   6267                6268              6269        6270  \
# temp             44.83                44.8             44.75       44.77
# location        Fenway  Financial District  Haymarket Square   North End
# clouds            0.88                0.89              0.89        0.89
# pressure        1000.7              1000.7           1000.69     1000.69
# rain               NaN                 NaN               NaN         NaN
# time_stamp  1543819974          1543819974        1543819974  1543819974
# humidity          0.96                0.96              0.96        0.96
# wind              1.53                1.53              1.53        1.53
#
#                      6271                     6272           6273  \
# temp                44.72                    44.85          44.82
# location    North Station  Northeastern University  South Station
# clouds               0.89                     0.88           0.89
# pressure          1000.69                  1000.71         1000.7
# rain                  NaN                      NaN            NaN
# time_stamp     1543819974               1543819974     1543819974
# humidity             0.96                     0.96           0.96
# wind                 1.52                     1.54           1.54
#
#                         6274        6275
# temp                   44.78       44.69
# location    Theatre District    West End
# clouds                  0.89        0.89
# pressure              1000.7      1000.7
# rain                     NaN         NaN
# time_stamp        1543819974  1543819974
# humidity                0.96        0.96
# wind                    1.54        1.52
#
# [8 rows x 6276 columns]

# %%
# practice problem on merged or joined dataset

# %% [markdown]
# ## Groupby

# %%
# total distance miles done based on cab_type
sum_distance = cab_rides.groupby('cab_type')[['distance']].sum()
sum_distance
# Out:
#            distance
# cab_type
# Lyft      672293.79
# Uber      845136.48

# %%
# total spent on cab_type
sum_price = cab_rides.groupby('cab_type')[['price']].sum()
sum_price
# Out:
#                price
# cab_type
# Lyft      5333957.98
# Uber      5221435.00

# %%
# average temperature based on location
weather.groupby('location')[['temp']].mean()
# Out:
#                               temp
# location
# Back Bay                 39.082122
# Beacon Hill              39.047285
# Boston University        39.047744
# Fenway                   38.964379
# Financial District       39.410822
# Haymarket Square         39.067897
# North End                39.090841
# North Station            39.035315
# Northeastern University  38.975086
# South Station            39.394092
# Theatre District         38.986711
# West End                 38.983403

# %%
# averages based on location
weather.groupby('location').mean()
# Out:
#                               temp    clouds     pressure      rain  \
# location
# Back Bay                 39.082122  0.678432  1008.447820  0.056012
# Beacon Hill              39.047285  0.677801  1008.448356  0.057097
# Boston University        39.047744  0.679235  1008.459254  0.054688
# Fenway                   38.964379  0.679866  1008.453289  0.054863
# Financial District       39.410822  0.676730  1008.435793  0.061352
# Haymarket Square         39.067897  0.676711  1008.445239  0.059593
# North End                39.090841  0.676730  1008.441912  0.058712
# North Station            39.035315  0.676998  1008.442811  0.056542
# Northeastern University  38.975086  0.678317  1008.444168  0.054197
# South Station            39.394092  0.677495  1008.438031  0.059537
# Theatre District         38.986711  0.677763  1008.444742  0.060214
# West End                 38.983403  0.677247  1008.441090  0.058803
#
#                            time_stamp  humidity      wind
# location
# Back Bay                 1.543857e+09  0.764073  6.778528
# Beacon Hill              1.543857e+09  0.765048  6.810325
# Boston University        1.543857e+09  0.763786  6.692180
# Fenway                   1.543857e+09  0.767266  6.711721
# Financial District       1.543857e+09  0.754837  6.860019
# Haymarket Square         1.543857e+09  0.764837  6.843193
# North End                1.543857e+09  0.764054  6.853117
# North Station            1.543857e+09  0.765545  6.835755
# Northeastern University  1.543857e+09  0.767648  6.749426
# South Station            1.543857e+09  0.755468  6.848948
# Theatre District         1.543857e+09  0.767992  6.834302
# West End                 1.543857e+09  0.767266  6.816233

# %%
# practice problem on merged or joined dataset

# %% [markdown]
# ## Aggregate

# %% [markdown]
# ## Apply

# %% [markdown]
# ## Lambda
